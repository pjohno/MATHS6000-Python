# %% [markdown]
# <div style='text-align: center;'>
# <img src="images/maths6000-banner.png" alt="image" width="80%" height="auto">
# </div>

# %% [markdown]
# # Running Notebooks on VSCode (AppsAnywhere)
#
# From the `AppsAnywhere` window, launch VSCode, open a folder on your onedrive and make sure normal python files run as we covered in the other notebook:
# [MATHS6000-running-vscode](https://github.com/pjohno/MATHS6000-Python/blob/main/MATHS6000-running-vscode.ipynb).
#
# Now create a new file called `example.ipynb`, or select Jupyter notebook from the menu
# <div style='text-align: left;'>
# <img src="images/ana-06.png" alt="image" width="30%" height="auto">
# </div>

# %% [markdown]
# Click `+ Code` to create a coding cell, and then add some code into the first cell.
#
# ```
# import numpy
#
# x = numpy.array( [ 0.0 , 1.0 , 2.0 , 3.0 ] )
#
# y = x * x
#
# print("y:=",y)
# ```
#
# <div style='text-align: left;'>
# <img src="images/2026/Screenshot132605.png" alt="image" width="60%" height="auto">
# </div>

# %% [markdown]
# Now click to `Select Kernel` on the top right
#
# <div style='text-align: left;'>
# <img src="images/2026/Screenshot132618.png" alt="image" width="30%" height="auto">
# </div>

# %% [markdown]
# First install the suggested extensions
# <div style='text-align: left;'>
# <img src="images/2026/Screenshot132627.png" alt="image" width="70%" height="auto">
# </div>

# %% [markdown]
# Then proceed to select a kernel
# <div style='text-align: left;'>
# <img src="images/2026/Screenshot132644.png" alt="image" width="60%" height="auto">
# </div>

# %% [markdown]
# Then select the `Anaconda3` one (make sure you enabled the interpreter by opening a python file first)
# <div style='text-align: left;'>
# <img src="images/2026/Screenshot132706.png" alt="image" width="60%" height="auto">
# </div>

# %% [markdown]
# Next time you run the cell by clicking on the play button on the left hand side, the cell should generate some output.
# <div style='text-align: left;'>
# <img src="images/2026/Screenshot132745.png" alt="image" width="60%" height="auto">
# </div>
